# %%
import mysql.connector

# RDS instance details
db_endpoint = 'database2.cnunqj562ud9.us-east-1.rds.amazonaws.com'
db_port = 3306
db_user = 'admin'
db_password = 'admin123'
db_name = 'linkedinjobposting_lab1'


def print_query_data(query):
    cursor.execute(query)
    # Fetch all the results
    results = cursor.fetchall()
    # Process the results
    for row in results:
        print(row)

def add_triggers(query):
    cursor.execute(query)

# Define the name of the stored procedure you want to create
procedure_name = "GetSkillsAbrByCompany"
# Define the SQL statement for the stored procedure
procedure_sql = """
CREATE PROCEDURE {0}(IN companyID_input BIGINT)
BEGIN
   SELECT name AS company_name, skill_abr, COUNT(js.job_id) AS job_count
   FROM JobSkills js
   JOIN JobPosting jp ON js.job_id = jp.job_id
   JOIN Companies c ON jp.company_id = c.company_id
   WHERE c.company_id = companyID_input
   GROUP BY skill_abr, company_name
   ORDER BY job_count DESC;
END;
""".format(procedure_name)

# Define the name of the stored procedure you want to create
procedure_name1 = "UpdateJobPostingSalary1"
# Define the SQL statement for the stored procedure
procedure_sql1 = """
CREATE PROCEDURE {0}(IN p_job_ID BIGINT, newSalary DECIMAL(10,2))
BEGIN 
	UPDATE JobPosting
    SET max_salary = newSalary 
    WHERE job_id = p_job_ID;
END
""".format(procedure_name1)

# This trigger ensures that if someone tries to update a job posting with an expiry date that is earlier than the current expiry date, the closed_time is updated to the current time, indicating that the job posting is now closed.

CLOSED_JOB_POSTING_TRIGGER= """
    CREATE TRIGGER BeforeJobPostingUpdate
    BEFORE UPDATE ON JobPosting
    FOR EACH ROW
    BEGIN
        IF NEW.expiry < OLD.expiry THEN
            SET NEW.closed_time = NOW();
        END IF;
    END;
"""

# This trigger creates a log entry in the JobPostingLog table whenever a new job posting is inserted into the Jobposting table. The log entry includes the job_id, company_id, title, and the timestamp of the insertion.

JOB_POSTING_LOG_TRIGGER = """
CREATE TRIGGER AfterJobPostingInsert
AFTER INSERT ON JobPosting
FOR EACH ROW
BEGIN
  INSERT INTO JobPostingLog (job_id, company_id, title, inserted_at)
  VALUES (NEW.job_id, NEW.company_id, NEW.title, NOW());
END;
"""


# In summary, this trigger creates a notification in the NotificationLog table whenever skills associated with a job are updated in the Jobskills table. The notification includes a message indicating the job ID and specifies the recipient as the HR Department. The timestamp of the notification is also recorded.

NOTIFICATION_LOG_TRIGGER = """
CREATE TRIGGER AfterSkillsUpdate
AFTER UPDATE ON JobSkills
FOR EACH ROW
BEGIN
  INSERT INTO NotificationLog (message, recipient, sent_at)
  VALUES ('Skills for job ' or NEW.job_id or ' have been updated.', 'HR Department', NOW());
END;
"""

# This trigger creates a notification in the NotificationLog table whenever a new skill is inserted into the Jobskills table. The trigger checks if the skill abbreviation is 'RemoteWork'. If it is, a notification is created, indicating that remote work skills have been added for a specific job. The recipient is set to the 'Remote Work Department', and the timestamp of the notification is also recorded.

NEW_SKILL_INSERT_TRIGGER = """
CREATE TRIGGER AfterSkillsForRemoteWorkingInsert
AFTER INSERT ON JobSkills
FOR EACH ROW
BEGIN
  IF NEW.skill_abr = 'RemoteWork' THEN
    INSERT INTO NotificationLog (message, recipient, sent_at)
    VALUES ('Remote work skills added for job ' OR NEW.job_id, 'Remote Work Department', NOW());
  END IF;
END;
"""


MAXMIN_SALARY = """
        WITH ITCompanies AS (
            SELECT c.state, jp.max_salary, jp.min_salary
            FROM Companies c
            JOIN CompanyIndustries ci ON c.company_id = ci.company_id
            JOIN JobPosting jp ON c.company_id = jp.company_id
            WHERE ci.industry = 'Nonprofit Organization Management'
        )
        SELECT state,
            max_salary AS max_salary,
            min_salary AS min_salary,
            AVG(max_salary) OVER (PARTITION BY state) AS avg_max_salary,
            AVG(min_salary) OVER (PARTITION BY state) AS avg_min_salary
        FROM ITCompanies;
        """

COMPANIES_SPECIFIC_CITY = """
        WITH CompanyEmployeeCounts AS (
            SELECT c.name, c.city, ec.employee_count,
           AVG(ec.employee_count) OVER (PARTITION BY c.city) AS avg_employee_count
            FROM Companies c
            LEFT JOIN EmployeesCount ec ON c.company_id = ec.company_id
        )   
        SELECT name, city, avg_employee_count
            FROM CompanyEmployeeCounts
            WHERE city = 'New York';
        """

JOBROLL_SPECIFIC_SPECIALITY = """
        WITH CompanyJobSkills AS (
        SELECT c.name AS 'Job Roll', cs.speciality, js.skill_abr,
            ROW_NUMBER() OVER (PARTITION BY c.name, cs.speciality, js.skill_abr) AS rn
            FROM Companies c
            JOIN CompanySpecialities cs ON c.company_id = cs.company_id
            JOIN JobPosting jp ON c.company_id = jp.company_id
            JOIN JobSkills js ON jp.job_id = js.job_id
        )
        SELECT 'Job Roll', speciality, skill_abr
            FROM CompanyJobSkills
            WHERE speciality = 'Financial Services' AND skill_abr = 'ACCT'
            AND rn = 1
            ORDER BY 'Job Roll';
        """

FIRST_CTE_BENEFITS = """
        WITH num_benefits as (
	    SELECT job_id, count(distinct type) as num_benefits 
	        FROM Benefits 
	        GROUP BY 1
        ), 
        -- # Getting avg number of benefits in the next CTE
        avg_benefits as (
        SELECT avg(num_benefits) as avg_benefits_count 
            FROM num_benefits
        )
        SELECT n.job_id, jp.company_id, c.name as company_name, jp.title, num_benefits 
            FROM num_benefits n 
            INNER JOIN JobPosting jp 
            ON n.job_id = jp.job_id 
            INNER JOIN Companies c
            ON  jp.company_id = c.company_id
            WHERE num_benefits >= (select avg_benefits_count from avg_benefits)
            ORDER BY num_benefits desc;
        """


AVERAGE_SALARY_BY_EACH_INDUSTRY = """
        with avg_salary_by_industry as (
        select industry,  round(avg(min_salary),3) as avg_salary 
            from JobPosting jp  
            inner join CompanyIndustries ci 
            on jp.company_id = ci.company_id 
            where industry is not null 
            and coalesce(min_salary,0) > 0
            group by 1
        ), 
        ranking_salary as (
        select industry, avg_salary, 
            dense_rank() over (order by avg_salary desc) as salary_rank
            from avg_salary_by_industry
        ) 
        select * from ranking_salary where salary_rank<=3
            order by salary_rank;
        """

TOP_SKILL_BY_EACH_INDUSTRY = """
        with industry_skill_count as (
	    select ci.industry as company_industry, jp.job_id, js.skill_abr
	        from JobSkills js
	        inner join JobPosting jp 
	        on js.job_id = jp.job_id 
	        inner join CompanyIndustries ci
	        on jp.company_id = ci.company_id
	        group by 1,2,3
        ), 
        skill_count_raw as (
        select company_industry, skill_abr, 
            count(distinct job_id) as job_count 
            from industry_skill_count
            group by 1,2
        ), 
        skill_ranking as (
        select company_industry, skill_abr, job_count,
            dense_rank() over (partition by company_industry order by job_count desc) as skill_rank
            from skill_count_raw
        ) 
        select * from skill_ranking where skill_rank=1
            order by company_industry, job_count desc;
        """

MAX_EMPLOYEE_GROWTH_COUNT = """ 
        with max_min_emp_count_raw as (
        select company_id, 
        # Casting varchar to timestamp in case data type is not already datetime
            cast(time_recorded_ts as datetime) as date_time_stamp, 
            employee_count 
            from EmployeesCount
            where time_recorded_ts is not null 
            and coalesce(employee_count,0)>0
            group by 1,2,3
        ), 
        min_max_rank as (
            select company_id, date_time_stamp, employee_count, 
        # Using row number since we want unique row for a rank, dense rank may show duplicates
        # Creating 2 ranks - 1 for earliest and 1 for latest
            row_number() over (partition by company_id order by date_time_stamp) as min_rank, 
            row_number() over (partition by company_id order by date_time_stamp desc) as max_rank
            from  max_min_emp_count_raw
        ),
        
        growth_calc as (
            select coalesce(mn.company_id, mx.company_id) as company_id, 
        # Including condition to make growth % as 0 if denominator is 0, else do the actual percentage change
            case when coalesce(mn.earliest_emp_count,0)>0 then 
	                (coalesce(mx.latest_emp_count,0) - coalesce(mn.earliest_emp_count,0))*100/coalesce(mn.earliest_emp_count,0)
                     else 0 end as emp_count_growth_change_percentage from
                    (select company_id, employee_count as earliest_emp_count from min_max_rank where min_rank=1) mn 
                    left join 
                    (select company_id, employee_count as latest_emp_count from min_max_rank where max_rank=1) mx 
                    on mn.company_id = mx.company_id
        )
            select c.name as company_name, gc.* from 
            growth_calc gc inner join Companies c 
            on gc.company_id = c.company_id 
            order by emp_count_growth_change_percentage desc;
            """

JOB_OPENINGS_WITH_HIGHEST_NUMBER_OF_OPENINGS ="""
            select * from
            (
	        select ci.industry as company_industry, 
                count(distinct job_id) as jobs_count
	            from JobPosting jp 
	            inner join CompanyIndustries ci
	            on jp.company_id = ci.company_id
                where jp.closed_time is not null
	            group by 1
                order by jobs_count desc
            ) s
            limit 1;
            """

FULL_TIME_JOBS = """
            with required_benefits_jobs as (
	        select job_id 
	            from Benefits 
	            where lower(trim(type)) in ('401k', 'medical insurance', 'dental insurance')
	            group by 1
            )
            select count(distinct jp.job_id) as jobs_count 
                from JobPosting jp inner join Companies c
                on jp.company_id = c.company_id 
                inner join required_benefits_jobs ben 
                on jp.job_id = ben.job_id
                where lower(trim(c.state)) in ('ca', 'california'); """

HIGHEST_NUMBER_OF_SPECIALITIES ="""
            with spec_count as (
	        select industry, c.company_id, c.name as company_name,
	            count(distinct speciality) as specialities_count 
	            from CompanySpecialities cs inner join Companies c
	            on cs.company_id = c.company_id
                inner join CompanyIndustries ci 
                on ci.company_id = c.company_id
	            group by 1,2,3
            ),
            spec_rank as (
	        select sc.*, 
	            dense_rank() over (partition by industry order by specialities_count desc) as sp_rank
	            from spec_count sc
            )
            select * from spec_rank 
                where sp_rank=1 
                order by specialities_count desc;
                """

COUNT_OF_INTERNSHIPS = """
        select c.name as company_name, c.company_size, jp.description as job_description,
            count(distinct job_id) as jobs_count
            from JobPosting jp 
            inner join Companies c
            on jp.company_id = c.company_id
            where jp.closed_time is not null
            and lower(trim(jp.work_type)) = 'internship'
            group by 1,2,3 
            order by jobs_count desc;
            """


try:
    # Connect to the RDS database
    connection = mysql.connector.connect(
        host=db_endpoint,
        port=db_port,
        user=db_user,
        password=db_password,
        database=db_name
    )

    if connection.is_connected():
        print(f"Connected to {db_endpoint} on port {db_port} as user {db_user} to database {db_name}")
        
        # Create a cursor for database operations
        cursor = connection.cursor()

        # Execute Procedure
        print("create stored procedure for skills by company and call the procedure")
        add_triggers(procedure_sql)
        cursor.callproc(procedure_name,[1016])
        print("create stored procedure for Updating new salary to max salary and call the procedure")
        add_triggers(procedure_sql1)
        cursor.callproc(procedure_name1,[133114754, 80000.00])
        # Execute Triggers
        print("This trigger creates a notification in the NotificationLog table whenever skills associated with a job are updated in the Jobskills table.")
        add_triggers(NOTIFICATION_LOG_TRIGGER)
        print("This trigger creates a notification in the NotificationLog table whenever a new skill is inserted into the Jobskills table.")
        add_triggers(NEW_SKILL_INSERT_TRIGGER)
        print("This trigger creates a log entry in the JobPostingLog table whenever a new job posting is inserted into the Jobposting table.")
        add_triggers(JOB_POSTING_LOG_TRIGGER)
        print("This trigger indicates that the job posting is now closed.")
        add_triggers(CLOSED_JOB_POSTING_TRIGGER)
        # Define your SQL SELECT statement
        print ("Calculate average maximum and minimum salaries for Nonprofit Organization Management companies while preserving the details of each company within the state")
        print_query_data(MAXMIN_SALARY)
        print ("List all companies in a specific city and their average employee counts.")
        print_query_data(COMPANIES_SPECIFIC_CITY)
        print ("Find companies job roll with a specific speciality that also have job postings with a certain skill requirement:")
        print_query_data(JOBROLL_SPECIFIC_SPECIALITY)
        print("Average # benefits per job and details of jobs offering higher than the average # of benefits")
        print_query_data(FIRST_CTE_BENEFITS)
        print ("Find the average salary by each job industry. Rank to find the top 3 industries by avg salary (joins and window function)")
        print_query_data(AVERAGE_SALARY_BY_EACH_INDUSTRY)
        print("Find the top skill for each job industry")
        print_query_data(TOP_SKILL_BY_EACH_INDUSTRY)
        print ("Which company has shown max employee count growth % over time? (headcount at latest ts - head count at earliest ts)/head count at earliest ts deduping and excluding null values")
        print_query_data(MAX_EMPLOYEE_GROWTH_COUNT)
        print(" Which job industry has the highest number of openings, Highest number of openings would mean the job_id that don't have a closed time yet")
        print_query_data(JOB_OPENINGS_WITH_HIGHEST_NUMBER_OF_OPENINGS)
        print ("How many full time jobs offer medical, dental, and 401k as benefits anda have HQ in California? Filtering for all jobs with the requried benefits")
        print_query_data(FULL_TIME_JOBS)
        print ("Which companies have the highest number of specialties by industry?")
        print_query_data(HIGHEST_NUMBER_OF_SPECIALITIES)
        print("What is the count of internships available with company name, size and job description?")
        print_query_data(COUNT_OF_INTERNSHIPS)
        
        
        
        
        

except mysql.connector.Error as err:
    print(f"Error: {err}")
finally:
    # Close the cursor and connection
    if 'cursor' in locals():
        cursor.close()
    if 'connection' in locals():
        connection.close()
        print("Database connection closed.")
# Out:
# Connected to database2.cnunqj562ud9.us-east-1.rds.amazonaws.com on port 3306 as user admin to database linkedinjobposting_lab1
# create stored procedure for skills by company and call the procedure
# create stored procedure for Updating new salary to max salary and call the procedure
# This trigger creates a notification in the NotificationLog table whenever skills associated with a job are updated in the Jobskills table.
# This trigger creates a notification in the NotificationLog table whenever a new skill is inserted into the Jobskills table.
# This trigger creates a log entry in the JobPostingLog table whenever a new job posting is inserted into the Jobposting table.
# This trigger indicates that the job posting is now closed.
# Calculate average maximum and minimum salaries for Nonprofit Organization Management companies while preserving the details of each company within the state
# ('alabama', Decimal('37000'), Decimal('33000'), Decimal('37000.0000'), Decimal('33000.0000'))
# ('alabama', None, None, Decimal('37000.0000'), Decimal('33000.0000'))
# ('arizona', None, None, Decimal('55189.0000'), Decimal('45052.0000'))
# ('arizona', None, None, Decimal('55189.0000'), Decimal('45052.0000'))
# ('arizona', None, None, Decimal('55189.0000'), Decimal('45052.0000'))
# ('arizona', None, None, Decimal('55189.0000'), Decimal('45052.0000'))
# ('arizona', None, None, Decimal('55189.0000'), Decimal('45052.0000'))
# ('arizona', Decimal('55189'), Decimal('45052'), Decimal('55189.0000'), Decimal('45052.0000'))
# ('arizona', None, None, Decimal('55189.0000'), Decimal('45052.0000'))
# ('arkansas', None, None, None, None)
# ('baden-wurttemberg', Decimal('30'), Decimal('26'), Decimal('17351.3333'), Decimal('14015.6667'))
# ('baden-wurttemberg', None, None, Decimal('17351.3333'), Decimal('14015.6667'))
# ('baden-wurttemberg', Decimal('52000'), Decimal('42000'), Decimal('17351.3333'), Decimal('14015.6667'))
# ('baden-wurttemberg', Decimal('24'), Decimal('21'), Decimal('17351.3333'), Decimal('14015.6667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('168120'), Decimal('125695'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('110'), Decimal('95'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('68725'), Decimal('67725'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('28'), Decimal('28'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('105000'), Decimal('82000'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('69600'), Decimal('69600'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('80000'), Decimal('77000'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('23'), Decimal('22'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('23'), Decimal('22'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('74093'), Decimal('61211'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('75000'), Decimal('75000'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('28'), Decimal('27'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('180000'), Decimal('143000'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('25'), Decimal('20'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('26'), Decimal('21'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('24'), Decimal('22'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('26'), Decimal('20'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('28'), Decimal('24'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('28'), Decimal('21'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('32'), Decimal('26'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('22'), Decimal('17'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('160000'), Decimal('140000'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('21'), Decimal('18'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('155000'), Decimal('135000'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('25'), Decimal('22'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('33'), Decimal('31'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('6592'), Decimal('5425'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('87000'), Decimal('80000'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('74093'), Decimal('61211'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', Decimal('23'), Decimal('22'), Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('california', None, None, Decimal('43458.2667'), Decimal('37444.1667'))
# ('connecticut', None, None, None, None)
# ('connecticut', None, None, None, None)
# ('florida', None, None, None, None)
# ('florida', None, None, None, None)
# ('florida', None, None, None, None)
# ('florida', None, None, None, None)
# ('florida', None, None, None, None)
# ('florida', None, None, None, None)
# ('georgia', None, None, Decimal('150000.0000'), Decimal('90000.0000'))
# ('georgia', Decimal('150000'), Decimal('90000'), Decimal('150000.0000'), Decimal('90000.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', Decimal('14'), Decimal('14'), Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', Decimal('65000'), Decimal('60000'), Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', Decimal('51000'), Decimal('49000'), Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('illinois', None, None, Decimal('38671.3333'), Decimal('36338.0000'))
# ('indiana', Decimal('20'), Decimal('17'), Decimal('20.0000'), Decimal('17.0000'))
# ('indiana', None, None, Decimal('20.0000'), Decimal('17.0000'))
# ('maine', None, None, Decimal('150000.0000'), Decimal('125000.0000'))
# ('maine', None, None, Decimal('150000.0000'), Decimal('125000.0000'))
# ('maine', Decimal('150000'), Decimal('125000'), Decimal('150000.0000'), Decimal('125000.0000'))
# ('maryland', Decimal('65000'), Decimal('55000'), Decimal('69000.0000'), Decimal('60000.0000'))
# ('maryland', Decimal('73000'), Decimal('65000'), Decimal('69000.0000'), Decimal('60000.0000'))
# ('maryland', None, None, Decimal('69000.0000'), Decimal('60000.0000'))
# ('massachusetts', Decimal('165000'), Decimal('116100'), Decimal('82515.0000'), Decimal('58062.5000'))
# ('massachusetts', None, None, Decimal('82515.0000'), Decimal('58062.5000'))
# ('massachusetts', None, None, Decimal('82515.0000'), Decimal('58062.5000'))
# ('Massachusetts', None, None, Decimal('82515.0000'), Decimal('58062.5000'))
# ('massachusetts', Decimal('30'), Decimal('25'), Decimal('82515.0000'), Decimal('58062.5000'))
# ('michigan', None, None, Decimal('63000.0000'), Decimal('55000.0000'))
# ('michigan', None, None, Decimal('63000.0000'), Decimal('55000.0000'))
# ('michigan', None, None, Decimal('63000.0000'), Decimal('55000.0000'))
# ('michigan', None, None, Decimal('63000.0000'), Decimal('55000.0000'))
# ('michigan', Decimal('61000'), Decimal('55000'), Decimal('63000.0000'), Decimal('55000.0000'))
# ('michigan', Decimal('65000'), Decimal('55000'), Decimal('63000.0000'), Decimal('55000.0000'))
# ('michigan', None, None, Decimal('63000.0000'), Decimal('55000.0000'))
# ('michigan', None, None, Decimal('63000.0000'), Decimal('55000.0000'))
# ('minnesota', None, None, None, None)
# ('montana', None, None, None, None)
# ('new jersey', None, None, Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', Decimal('50000'), Decimal('45000'), Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', Decimal('90000'), Decimal('75000'), Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', None, None, Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', None, None, Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', Decimal('90000'), Decimal('75000'), Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', None, None, Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', None, None, Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', None, None, Decimal('80000.0000'), Decimal('67500.0000'))
# ('new jersey', Decimal('90000'), Decimal('75000'), Decimal('80000.0000'), Decimal('67500.0000'))
# ('new york', Decimal('124800'), Decimal('115000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('50000'), Decimal('50000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('80000'), Decimal('70000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('65000'), Decimal('60000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('26'), Decimal('16'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('26'), Decimal('16'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('17'), Decimal('15'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', None, None, Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('50'), Decimal('30'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', None, None, Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('60000'), Decimal('55000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('26'), Decimal('22'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', None, None, Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('45000'), Decimal('41000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('48000'), Decimal('40000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', None, None, Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('75000'), Decimal('65000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('40000'), Decimal('38000'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('26'), Decimal('16'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('25'), Decimal('24'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('40'), Decimal('23'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', Decimal('20'), Decimal('18'), Decimal('32669.7778'), Decimal('29676.6667'))
# ('new york', None, None, Decimal('32669.7778'), Decimal('29676.6667'))
# ('north carolina', None, None, None, None)
# ('north carolina', None, None, None, None)
# ('Not Available', Decimal('120000'), Decimal('100000'), Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', None, None, Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', None, None, Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', Decimal('27'), Decimal('25'), Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', Decimal('80000'), Decimal('65000'), Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', Decimal('100000'), Decimal('60000'), Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', Decimal('76000'), Decimal('70000'), Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', Decimal('125000'), Decimal('110000'), Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', None, None, Decimal('83504.5000'), Decimal('67504.1667'))
# ('Not Available', None, None, Decimal('83504.5000'), Decimal('67504.1667'))
# ('ohio', Decimal('19'), Decimal('17'), Decimal('19.0000'), Decimal('17.0000'))
# ('ohio', None, None, Decimal('19.0000'), Decimal('17.0000'))
# ('oregon', Decimal('22'), Decimal('19'), Decimal('22.0000'), Decimal('19.0000'))
# ('oregon', None, None, Decimal('22.0000'), Decimal('19.0000'))
# ('pennsylvania', None, None, Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', Decimal('15'), Decimal('14'), Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', None, None, Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', Decimal('135000'), Decimal('115000'), Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', None, None, Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', Decimal('135000'), Decimal('115000'), Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', Decimal('75000'), Decimal('65000'), Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', None, None, Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', None, None, Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', None, None, Decimal('86253.7500'), Decimal('73753.5000'))
# ('pennsylvania', None, None, Decimal('86253.7500'), Decimal('73753.5000'))
# ('rhode island', Decimal('100000'), Decimal('80000'), Decimal('100000.0000'), Decimal('80000.0000'))
# ('tennessee', None, None, None, None)
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', Decimal('65000'), Decimal('60000'), Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', Decimal('130000'), Decimal('110000'), Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', Decimal('28'), Decimal('19'), Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('texas', None, None, Decimal('65009.3333'), Decimal('56673.0000'))
# ('virginia', Decimal('45000'), Decimal('40000'), Decimal('50900.0000'), Decimal('43400.0000'))
# ('virginia', None, None, Decimal('50900.0000'), Decimal('43400.0000'))
# ('virginia', Decimal('56800'), Decimal('46800'), Decimal('50900.0000'), Decimal('43400.0000'))
# ('virginia', None, None, Decimal('50900.0000'), Decimal('43400.0000'))
# ('virginia', None, None, Decimal('50900.0000'), Decimal('43400.0000'))
# ('virginia', None, None, Decimal('50900.0000'), Decimal('43400.0000'))
# ('virginia', None, None, Decimal('50900.0000'), Decimal('43400.0000'))
# ('washington', Decimal('225000'), Decimal('175000'), Decimal('120884.5000'), Decimal('94951.8333'))
# ('washington', None, None, Decimal('120884.5000'), Decimal('94951.8333'))
# ('washington', Decimal('110000'), Decimal('95000'), Decimal('120884.5000'), Decimal('94951.8333'))
# ('washington', Decimal('20'), Decimal('17'), Decimal('120884.5000'), Decimal('94951.8333'))
# ('washington', Decimal('65000'), Decimal('55000'), Decimal('120884.5000'), Decimal('94951.8333'))
# ('washington', None, None, Decimal('120884.5000'), Decimal('94951.8333'))
# ('washington', Decimal('210287'), Decimal('159694'), Decimal('120884.5000'), Decimal('94951.8333'))
# ('washington', Decimal('115000'), Decimal('85000'), Decimal('120884.5000'), Decimal('94951.8333'))
# ('wisconsin', Decimal('65000'), Decimal('55000'), Decimal('65000.0000'), Decimal('55000.0000'))
# List all companies in a specific city and their average employee counts.
# ('advantagecare physicians', 'new york', Decimal('12746.3818'))
# ('gen ii fund services', 'new york', Decimal('12746.3818'))
# ('gen ii fund services', 'new york', Decimal('12746.3818'))
# ('pamela love', 'new york', Decimal('12746.3818'))
# ('fohr', 'new york', Decimal('12746.3818'))
# ('atlas search', 'new york', Decimal('12746.3818'))
# ('atlas search', 'new york', Decimal('12746.3818'))
# ('atlas search', 'new york', Decimal('12746.3818'))
# ('atlas search', 'new york', Decimal('12746.3818'))
# ('atlas search', 'new york', Decimal('12746.3818'))
# ('advantagecare physicians', 'new york', Decimal('12746.3818'))
# ('gen ii fund services', 'new york', Decimal('12746.3818'))
# ('baccarat hotel & residences', 'new york', Decimal('12746.3818'))
# ('cmrg', 'new york', Decimal('12746.3818'))
# ('k health', 'new york', Decimal('12746.3818'))
# ('transfr', 'new york', Decimal('12746.3818'))
# ('madison square garden sports corp.', 'new york', Decimal('12746.3818'))
# ('everyday health group', 'new york', Decimal('12746.3818'))
# ('houseaccount', 'new york', Decimal('12746.3818'))
# ('zenotis group', 'new york', Decimal('12746.3818'))
# ('mindfull', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('marketaxess', 'new york', Decimal('12746.3818'))
# ('advice personnel', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('onedata software solutions', 'new york', Decimal('12746.3818'))
# ('mission staffing', 'new york', Decimal('12746.3818'))
# ('initiative', 'new york', Decimal('12746.3818'))
# ('nyc department of parks & recreation', 'new york', Decimal('12746.3818'))
# ('nyc department of parks & recreation', 'new york', Decimal('12746.3818'))
# ('nyc department of parks & recreation', 'new york', Decimal('12746.3818'))
# ('akam', 'new york', Decimal('12746.3818'))
# ('etf.com', 'new york', Decimal('12746.3818'))
# ('gen ii fund services', 'new york', Decimal('12746.3818'))
# ('gen ii fund services', 'new york', Decimal('12746.3818'))
# ('john hardy', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('marcum llp', 'new york', Decimal('12746.3818'))
# ('new york city economic development corporation', 'new york', Decimal('12746.3818'))
# ('domini impact investments llc', 'new york', Decimal('12746.3818'))
# ('next street', 'new york', Decimal('12746.3818'))
# ('phaxis', 'new york', Decimal('12746.3818'))
# ('phaxis', 'new york', Decimal('12746.3818'))
# ('phaxis', 'new york', Decimal('12746.3818'))
# ('phaxis', 'new york', Decimal('12746.3818'))
# ('madison square garden entertainment corp.', 'new york', Decimal('12746.3818'))
# ('madison square garden entertainment corp.', 'new york', Decimal('12746.3818'))
# ('morgan stanley', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('columbia university irving medical center', 'new york', Decimal('12746.3818'))
# ('mcgraw hill', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('marketaxess', 'new york', Decimal('12746.3818'))
# ('s&p global', 'new york', Decimal('12746.3818'))
# ('new york life insurance company', 'new york', Decimal('12746.3818'))
# ('skadden, arps, slate, meagher & flom llp and affiliates', 'new york', Decimal('12746.3818'))
# ('skadden, arps, slate, meagher & flom llp and affiliates', 'new york', Decimal('12746.3818'))
# ('davis polk & wardwell llp', 'new york', Decimal('12746.3818'))
# ('davis polk & wardwell llp', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('sportscapital', 'new york', Decimal('12746.3818'))
# ('sud recruiting', 'new york', Decimal('12746.3818'))
# ('sud recruiting', 'new york', Decimal('12746.3818'))
# ('sud recruiting', 'new york', Decimal('12746.3818'))
# ('sud recruiting', 'new york', Decimal('12746.3818'))
# ('sud recruiting', 'new york', Decimal('12746.3818'))
# ('sud recruiting', 'new york', Decimal('12746.3818'))
# ('vanguard x', 'new york', Decimal('12746.3818'))
# ('socotec usa', 'new york', Decimal('12746.3818'))
# ('socotec usa', 'new york', Decimal('12746.3818'))
# ('sud recruiting', 'new york', Decimal('12746.3818'))
# ('larson maddox', 'new york', Decimal('12746.3818'))
# ('larson maddox', 'new york', Decimal('12746.3818'))
# ('zenotis group', 'new york', Decimal('12746.3818'))
# ('wollman rink nyc', 'new york', Decimal('12746.3818'))
# ('droomdroom', 'new york', Decimal('12746.3818'))
# ('tandym group', 'new york', Decimal('12746.3818'))
# ('tandym group', 'new york', Decimal('12746.3818'))
# ('tandym group', 'new york', Decimal('12746.3818'))
# ('tandym group', 'new york', Decimal('12746.3818'))
# ('equitable', 'new york', Decimal('12746.3818'))
# ('bowlero corporation', 'new york', Decimal('12746.3818'))
# ('torch dental', 'new york', Decimal('12746.3818'))
# ('torch dental', 'new york', Decimal('12746.3818'))
# ('zentalis pharmaceuticals', 'new york', Decimal('12746.3818'))
# ('siterx', 'new york', Decimal('12746.3818'))
# ('siterx', 'new york', Decimal('12746.3818'))
# ('equitable', 'new york', Decimal('12746.3818'))
# ('equitable', 'new york', Decimal('12746.3818'))
# ('equitable', 'new york', Decimal('12746.3818'))
# ('cucunu corp', 'new york', Decimal('12746.3818'))
# ('planned parenthood of greater new york', 'new york', Decimal('12746.3818'))
# ('neo media world', 'new york', Decimal('12746.3818'))
# ('monday talent', 'new york', Decimal('12746.3818'))
# ('razorfish', 'new york', Decimal('12746.3818'))
# ('razorfish', 'new york', Decimal('12746.3818'))
# ('razorfish', 'new york', Decimal('12746.3818'))
# ('internova travel group', 'new york', Decimal('12746.3818'))
# ('internova travel group', 'new york', Decimal('12746.3818'))
# ('gigiid', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('icahn school of medicine at mount sinai', 'new york', Decimal('12746.3818'))
# ('msnbc', 'new york', Decimal('12746.3818'))
# ('j.crew', 'new york', Decimal('12746.3818'))
# ('j.crew', 'new york', Decimal('12746.3818'))
# ('guy carpenter', 'new york', Decimal('12746.3818'))
# ('wilson elser', 'new york', Decimal('12746.3818'))
# ('wilson elser', 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ('nsg - real estate & construction (noor staffing group)', 'new york', Decimal('12746.3818'))
# ('saks fifth avenue stores (sfa)', 'new york', Decimal('12746.3818'))
# ('saks fifth avenue stores (sfa)', 'new york', Decimal('12746.3818'))
# ('saks fifth avenue stores (sfa)', 'new york', Decimal('12746.3818'))
# ('saks fifth avenue stores (sfa)', 'new york', Decimal('12746.3818'))
# ('tag medstaffing', 'new york', Decimal('12746.3818'))
# ('tag medstaffing', 'new york', Decimal('12746.3818'))
# ('visdomur', 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ('morgan stanley', 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ("macy's", 'new york', Decimal('12746.3818'))
# ('mercer', 'new york', Decimal('12746.3818'))
# ('planned parenthood of greater new york', 'new york', Decimal('12746.3818'))
# ('planned parenthood of greater new york', 'new york', Decimal('12746.3818'))
# ('createme', 'new york', Decimal('12746.3818'))
# ('fabiani cohen & hall, llp', 'new york', Decimal('12746.3818'))
# ('swap health', 'new york', Decimal('12746.3818'))
# ('student world impact film festival (swiff)', 'new york', Decimal('12746.3818'))
# ('brooklyn robot foundry-manhattan east', 'new york', Decimal('12746.3818'))
# ('nielsen', 'new york', Decimal('12746.3818'))
# ('mercer', 'new york', Decimal('12746.3818'))
# ('equitable', 'new york', Decimal('12746.3818'))
# ('mercer', 'new york', Decimal('12746.3818'))
# ('mercer', 'new york', Decimal('12746.3818'))
# ('coach', 'new york', Decimal('12746.3818'))
# ('coach', 'new york', Decimal('12746.3818'))
# ('turner construction company', 'new york', Decimal('12746.3818'))
# ('turner construction company', 'new york', Decimal('12746.3818'))
# ('turner construction company', 'new york', Decimal('12746.3818'))
# ('turner construction company', 'new york', Decimal('12746.3818'))
# ('open systems technologies', 'new york', Decimal('12746.3818'))
# ('america needs you', 'new york', Decimal('12746.3818'))
# ('peloton interactive', 'new york', Decimal('12746.3818'))
# ('peloton interactive', 'new york', Decimal('12746.3818'))
# ('peloton interactive', 'new york', Decimal('12746.3818'))
# ('compass', 'new york', Decimal('12746.3818'))
# ('toppan merrill', 'new york', Decimal('12746.3818'))
# ('derris', 'new york', Decimal('12746.3818'))
# ('nasdaq private market', 'new york', Decimal('12746.3818'))
# ('emerald', 'new york', Decimal('12746.3818'))
# ('emerald', 'new york', Decimal('12746.3818'))
# ('michael kors', 'new york', Decimal('12746.3818'))
# ('finsight group inc (finsight)', 'new york', Decimal('12746.3818'))
# ('grey state apparel', 'new york', Decimal('12746.3818'))
# ('kinetic brands', 'new york', Decimal('12746.3818'))
# ('dandy', 'new york', Decimal('12746.3818'))
# ('attentive', 'new york', Decimal('12746.3818'))
# ('cash app', 'new york', Decimal('12746.3818'))
# ('cash app', 'new york', Decimal('12746.3818'))
# ('cash app', 'new york', Decimal('12746.3818'))
# ('equitable', 'new york', Decimal('12746.3818'))
# ('kinesso', 'new york', Decimal('12746.3818'))
# ('dl1961 premium denim', 'new york', Decimal('12746.3818'))
# ('levelup', 'new york', Decimal('12746.3818'))
# ('snapback digital', 'new york', Decimal('12746.3818'))
# ('headway', 'new york', Decimal('12746.3818'))
# ('elan jewels', 'new york', Decimal('12746.3818'))
# ('amtex systems inc.', 'new york', Decimal('12746.3818'))
# ('amtex systems inc.', 'new york', Decimal('12746.3818'))
# ('columbia department of biomedical informatics', 'new york', Decimal('12746.3818'))
# ('kinesso', 'new york', Decimal('12746.3818'))
# ('tech-nique partners', 'new york', Decimal('12746.3818'))
# ('effectv', 'new york', Decimal('12746.3818'))
# ('effectv', 'new york', Decimal('12746.3818'))
# ('onepointfive (opf.degree)', 'new york', Decimal('12746.3818'))
# ('a360media', 'new york', Decimal('12746.3818'))
# ('kim & serritella llp', 'new york', Decimal('12746.3818'))
# ('avenue one', 'new york', Decimal('12746.3818'))
# ('larson maddox', 'new york', Decimal('12746.3818'))
# ('majhi group', 'new york', Decimal('12746.3818'))
# ('danarys new york', 'new york', Decimal('12746.3818'))
# ('b&h photo video', 'new york', Decimal('12746.3818'))
# ('digital divide data (ddd)', 'new york', Decimal('12746.3818'))
# ('tbg | the bachrach group', 'new york', Decimal('12746.3818'))
# ('services for the underserved', 'new york', Decimal('12746.3818'))
# ('united staffing solutions (uss)', 'new york', Decimal('12746.3818'))
# ('bernard nickels & associates', 'new york', Decimal('12746.3818'))
# ('perennial resources international', 'new york', Decimal('12746.3818'))
# ('perennial resources international', 'new york', Decimal('12746.3818'))
# ('optionmetrics', 'new york', Decimal('12746.3818'))
# ('b&h photo video', 'new york', Decimal('12746.3818'))
# ('peloton interactive', 'new york', Decimal('12746.3818'))
# ('b&h photo video', 'new york', Decimal('12746.3818'))
# ('clarity recruiting', 'new york', Decimal('12746.3818'))
# ('clarity recruiting', 'new york', Decimal('12746.3818'))
# ('thom filicia inc.', 'new york', Decimal('12746.3818'))
# ('clear (clearme.com)', 'new york', Decimal('12746.3818'))
# ('clear (clearme.com)', 'new york', Decimal('12746.3818'))
# ('berke-weiss law pllc', 'new york', Decimal('12746.3818'))
# ('riskified', 'new york', Decimal('12746.3818'))
# ('glocomms', 'new york', Decimal('12746.3818'))
# ('giveffect', 'new york', Decimal('12746.3818'))
# ('pride health', 'new york', Decimal('12746.3818'))
# ('pride health', 'new york', Decimal('12746.3818'))
# ('coda search│staffing', 'new york', Decimal('12746.3818'))
# ('coda search│staffing', 'new york', Decimal('12746.3818'))
# ('coda search│staffing', 'new york', Decimal('12746.3818'))
# ('coda search│staffing', 'new york', Decimal('12746.3818'))
# ('free country', 'new york', Decimal('12746.3818'))
# ('saatva', 'new york', Decimal('12746.3818'))
# ('saatva', 'new york', Decimal('12746.3818'))
# ('amsale', 'new york', Decimal('12746.3818'))
# ('from, the digital transformation agency', 'new york', Decimal('12746.3818'))
# ('relatable (previously what do you meme?)', 'new york', Decimal('12746.3818'))
# ('network esc a division of network temps, inc.', 'new york', Decimal('12746.3818'))
# ('bowlero corporation', 'new york', Decimal('12746.3818'))
# ('hope community, inc.', 'new york', Decimal('12746.3818'))
# ('bcw global', 'new york', Decimal('12746.3818'))
# ('the titus school', 'new york', Decimal('12746.3818'))
# ('lolly.com', 'new york', Decimal('12746.3818'))
# ('suave brands company', 'new york', Decimal('12746.3818'))
# ('synergy interactive', 'new york', Decimal('12746.3818'))
# ('morgan stanley', 'new york', Decimal('12746.3818'))
# ('morgan stanley', 'new york', Decimal('12746.3818'))
# ('morgan stanley', 'new york', Decimal('12746.3818'))
# ('morgan stanley', 'new york', Decimal('12746.3818'))
# ('morgan stanley', 'new york', Decimal('12746.3818'))
# ('morgan stanley', 'new york', Decimal('12746.3818'))
# ('roll & hill', 'new york', Decimal('12746.3818'))
# ('roll & hill', 'new york', Decimal('12746.3818'))
# ('lambent services', 'new york', Decimal('12746.3818'))
# ('liberty law group (wall street nyc)', 'new york', Decimal('12746.3818'))
# ('synergy interactive', 'new york', Decimal('12746.3818'))
# ('synergy interactive', 'new york', Decimal('12746.3818'))
# ('synergy interactive', 'new york', Decimal('12746.3818'))
# ('atlantic group', 'new york', Decimal('12746.3818'))
# ('atlantic group', 'new york', Decimal('12746.3818'))
# ('atlantic group', 'new york', Decimal('12746.3818'))
# ('atlantic group', 'new york', Decimal('12746.3818'))
# ('atlantic group', 'new york', Decimal('12746.3818'))
# ('amsale', 'new york', Decimal('12746.3818'))
# ('metropolitan transportation authority', 'new york', Decimal('12746.3818'))
# ('american museum of natural history', 'new york', Decimal('12746.3818'))
# ('american museum of natural history', 'new york', Decimal('12746.3818'))
# ('american museum of natural history', 'new york', Decimal('12746.3818'))
# ('american museum of natural history', 'new york', Decimal('12746.3818'))
# ('guardian life', 'new york', Decimal('12746.3818'))
# ('guardian life', 'new york', Decimal('12746.3818'))
# ('harry winston', 'new york', Decimal('12746.3818'))
# ('revlon', 'new york', Decimal('12746.3818'))
# ('revlon', 'new york', Decimal('12746.3818'))
# ('american museum of natural history', 'new york', Decimal('12746.3818'))
# ('metropolitan transportation authority', 'new york', Decimal('12746.3818'))
# ('emblemhealth', 'new york', Decimal('12746.3818'))
# ('emblemhealth', 'new york', Decimal('12746.3818'))
# ('russell tobin', 'new york', Decimal('12746.3818'))
# ('russell tobin', 'new york', Decimal('12746.3818'))
# ('russell tobin', 'new york', Decimal('12746.3818'))
# ('russell tobin', 'new york', Decimal('12746.3818'))
# ('northpointe staffing professionals', 'new york', Decimal('12746.3818'))
# ('citistaffing', 'new york', Decimal('12746.3818'))
# ('epiq', 'new york', Decimal('12746.3818'))
# ('dna partners', 'new york', Decimal('12746.3818'))
# ('dna partners', 'new york', Decimal('12746.3818'))
# ('dna partners', 'new york', Decimal('12746.3818'))
# ("recruits lab (we're hiring)", 'new york', Decimal('12746.3818'))
# ('momentum worldwide', 'new york', Decimal('12746.3818'))
# ('the mount sinai hospital', 'new york', Decimal('12746.3818'))
# ('broadridge', 'new york', Decimal('12746.3818'))
# ('broadridge', 'new york', Decimal('12746.3818'))
# ('broadridge', 'new york', Decimal('12746.3818'))
# ('healthprecision', 'new york', Decimal('12746.3818'))
# ('david yurman', 'new york', Decimal('12746.3818'))
# ('atrium', 'new york', Decimal('12746.3818'))
# ('kate spade new york', 'new york', Decimal('12746.3818'))
# ('kate spade new york', 'new york', Decimal('12746.3818'))
# ('nextsource', 'new york', Decimal('12746.3818'))
# ('technosphere, inc.', 'new york', Decimal('12746.3818'))
# ('pri technology', 'new york', Decimal('12746.3818'))
# ('pri technology', 'new york', Decimal('12746.3818'))
# ('eclaro', 'new york', Decimal('12746.3818'))
# ('atrium', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('forrest solutions', 'new york', Decimal('12746.3818'))
# ('forrest solutions', 'new york', Decimal('12746.3818'))
# ('club monaco', 'new york', Decimal('12746.3818'))
# ('atrium', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('atrium', 'new york', Decimal('12746.3818'))
# ('atrium', 'new york', Decimal('12746.3818'))
# ('atrium', 'new york', Decimal('12746.3818'))
# ('atrium', 'new york', Decimal('12746.3818'))
# ('atrium', 'new york', Decimal('12746.3818'))
# ('eurasia group', 'new york', Decimal('12746.3818'))
# ('cardiovascular research foundation', 'new york', Decimal('12746.3818'))
# ('captivate, llc', 'new york', Decimal('12746.3818'))
# ('nyc health + hospitals', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('solomon page', 'new york', Decimal('12746.3818'))
# ('solomon page', 'new york', Decimal('12746.3818'))
# ('synechron', 'new york', Decimal('12746.3818'))
# ('healthfirst', 'new york', Decimal('12746.3818'))
# ('healthfirst', 'new york', Decimal('12746.3818'))
# ('hospital for special surgery', 'new york', Decimal('12746.3818'))
# ('hospital for special surgery', 'new york', Decimal('12746.3818'))
# ('hospital for special surgery', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('aspca', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('24 seven talent', 'new york', Decimal('12746.3818'))
# ('bny mellon', 'new york', Decimal('12746.3818'))
# ('mayzon', 'new york', Decimal('12746.3818'))
# ('axinn, veltrop & harkrider llp', 'new york', Decimal('12746.3818'))
# ('eclaro', 'new york', Decimal('12746.3818'))
# ('eclaro', 'new york', Decimal('12746.3818'))
# ('eclaro', 'new york', Decimal('12746.3818'))
# ('eclaro', 'new york', Decimal('12746.3818'))
# ('the quest organization', 'new york', Decimal('12746.3818'))
# ('the quest organization', 'new york', Decimal('12746.3818'))
# ('bny mellon', 'new york', Decimal('12746.3818'))
# ('oppenheimer & co. inc.', 'new york', Decimal('12746.3818'))
# ('bny mellon', 'new york', Decimal('12746.3818'))
# ('bny mellon', 'new york', Decimal('12746.3818'))
# ('bny mellon', 'new york', Decimal('12746.3818'))
# ('spectrum reach', 'new york', Decimal('12746.3818'))
# ('evercore', 'new york', Decimal('12746.3818'))
# ('exl', 'new york', Decimal('12746.3818'))
# ('exl', 'new york', Decimal('12746.3818'))
# ('fitch ratings', 'new york', Decimal('12746.3818'))
# ('spark foundry', 'new york', Decimal('12746.3818'))
# ('qsac (quality services for the autism community)', 'new york', Decimal('12746.3818'))
# ('kate spade new york', 'new york', Decimal('12746.3818'))
# ('tbg | the bachrach group', 'new york', Decimal('12746.3818'))
# ('tbg | the bachrach group', 'new york', Decimal('12746.3818'))
# ("jewish board of family and children's services", 'new york', Decimal('12746.3818'))
# ("jewish board of family and children's services", 'new york', Decimal('12746.3818'))
# ('edelman dxi', 'new york', Decimal('12746.3818'))
# ('qsac (quality services for the autism community)', 'new york', Decimal('12746.3818'))
# ('qsac (quality services for the autism community)', 'new york', Decimal('12746.3818'))
# ('qsac (quality services for the autism community)', 'new york', Decimal('12746.3818'))
# ('solomon page', 'new york', Decimal('12746.3818'))
# ('qsac (quality services for the autism community)', 'new york', Decimal('12746.3818'))
# ('united staffing solutions (uss)', 'new york', Decimal('12746.3818'))
# ('exhale spa', 'new york', Decimal('12746.3818'))
# ('met council', 'new york', Decimal('12746.3818'))
# ('met council', 'new york', Decimal('12746.3818'))
# ('met council', 'new york', Decimal('12746.3818'))
# ('met council', 'new york', Decimal('12746.3818'))
# ('dga security', 'new york', Decimal('12746.3818'))
# ('green key resources', 'new york', Decimal('12746.3818'))
# ('edelman', 'new york', Decimal('12746.3818'))
# ('iheartmedia', 'new york', Decimal('12746.3818'))
# ('iheartmedia', 'new york', Decimal('12746.3818'))
# ('colgate-palmolive', 'new york', Decimal('12746.3818'))
# ('colgate-palmolive', 'new york', Decimal('12746.3818'))
# ('publicis', 'new york', Decimal('12746.3818'))
# ('mcgraw hill', 'new york', Decimal('12746.3818'))
# ('new york life insurance company', 'new york', Decimal('12746.3818'))
# ('new york life insurance company', 'new york', Decimal('12746.3818'))
# ('edelman', 'new york', Decimal('12746.3818'))
# ('iheartmedia', 'new york', Decimal('12746.3818'))
# ('edelman', 'new york', Decimal('12746.3818'))
# ('edelman', 'new york', Decimal('12746.3818'))
# ('edelman', 'new york', Decimal('12746.3818'))
# ('edelman', 'new york', Decimal('12746.3818'))
# ('groupm', 'new york', Decimal('12746.3818'))
# ('tiaa', 'new york', Decimal('12746.3818'))
# ('amc networks', 'new york', Decimal('12746.3818'))
# ('unicef', 'new york', Decimal('12746.3818'))
# ('coach', 'new york', Decimal('12746.3818'))
# ('marsh', 'new york', Decimal('12746.3818'))
# ('jpmorgan chase & co.', 'new york', Decimal('12746.3818'))
# ('jpmorgan chase & co.', 'new york', Decimal('12746.3818'))
# ('pfizer', 'new york', Decimal('12746.3818'))
# ('pfizer', 'new york', Decimal('12746.3818'))
# ('pfizer', 'new york', Decimal('12746.3818'))
# ('pfizer', 'new york', Decimal('12746.3818'))
# ('pfizer', 'new york', Decimal('12746.3818'))
# ('pfizer', 'new york', Decimal('12746.3818'))
# ('nielsen', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('marsh', 'new york', Decimal('12746.3818'))
# ('mercer', 'new york', Decimal('12746.3818'))
# ('mercer', 'new york', Decimal('12746.3818'))
# ('mercer', 'new york', Decimal('12746.3818'))
# ('iheartmedia', 'new york', Decimal('12746.3818'))
# ('iheartmedia', 'new york', Decimal('12746.3818'))
# ('iheartmedia', 'new york', Decimal('12746.3818'))
# ('iheartmedia', 'new york', Decimal('12746.3818'))
# ('iheartmedia', 'new york', Decimal('12746.3818'))
# ('national hockey league (nhl)', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('guy carpenter', 'new york', Decimal('12746.3818'))
# ('sumitomo mitsui banking corporation', 'new york', Decimal('12746.3818'))
# ('sumitomo mitsui banking corporation', 'new york', Decimal('12746.3818'))
# ('sumitomo mitsui banking corporation', 'new york', Decimal('12746.3818'))
# ('sumitomo mitsui banking corporation', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('newmark', 'new york', Decimal('12746.3818'))
# ('nuveen, a tiaa company', 'new york', Decimal('12746.3818'))
# ('nuveen, a tiaa company', 'new york', Decimal('12746.3818'))
# ('vns health', 'new york', Decimal('12746.3818'))
# ('vns health', 'new york', Decimal('12746.3818'))
# ('vns health', 'new york', Decimal('12746.3818'))
# ('new york sports club', 'new york', Decimal('12746.3818'))
# ('new york sports club', 'new york', Decimal('12746.3818'))
# ('cohnreznick llp', 'new york', Decimal('12746.3818'))
# ('national general', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('nyu langone health', 'new york', Decimal('12746.3818'))
# ('newyork-presbyterian hospital', 'new york', Decimal('12746.3818'))
# ('rockstar games', 'new york', Decimal('12746.3818'))
# ('spark foundry', 'new york', Decimal('12746.3818'))
# ('national general', 'new york', Decimal('12746.3818'))
# ('national general', 'new york', Decimal('12746.3818'))
# ('popular bank', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('mount sinai health system', 'new york', Decimal('12746.3818'))
# ('easton architects, llp', 'new york', Decimal('12746.3818'))
# ('glocomms', 'new york', Decimal('12746.3818'))
# ('glocomms', 'new york', Decimal('12746.3818'))
# ('fund for public health in nyc', 'new york', Decimal('12746.3818'))
# ('fund for public health in nyc', 'new york', Decimal('12746.3818'))
# ('edbridge partners, llc', 'new york', Decimal('12746.3818'))
# ('cbs news and stations', 'new york', Decimal('12746.3818'))
# ('omd usa', 'new york', Decimal('12746.3818'))
# ...
# ('eventeny', 1, 'Overview\nWe are seeking a highly motivated and detailoriented Product Marketing Intern to join our team As a Product Marketing Intern you will have the opportunity to gain handson experience and contribute to the success of our companys product and mission \nYou will work closely with the marketing team to support various marketing initiatives and help drive product awareness adoption and growth This internship provides an excellent learning opportunity for individuals interested in pursuing a career in product marketing\nHeres what youll do\nAssist in the development and execution of product marketing strategies and campaignsConduct market research to identify customer needs preferences and competitive landscapeHelp create compelling product messaging and positioning that resonates with target audiencesCollaborate with crossfunctional teams including product sales customer success and design to gather information and ensure alignment on marketing initiativesAssist in the creation and editing of marketing collateral including sales decks compare pages onepagers case studies videos emails website content and moreSupport the planning and execution of product launches including coordinating timelines deliverables and promotional activitiesMonitor and analyze marketing campaign performance metrics and provide insights for optimizationAn analytical mindset plus a passion for data and solving complex problems\nHeres what we are looking for\nCurrently enrolled in a bachelors or masters degree program in marketing business or a related fieldStrong written and verbal communication skills Solid understanding of marketing principles and conceptsStrong content development experience such as blogging video creation and web designDetailoriented with excellent organizational and multitasking abilitiesAbility to work independently and collaborate effectively in a team environmentProactive attitude with a willingness to learn and take on new challengesAbility to work in a fastpaced startup environmentExperience with Adobe Premiere Pro After Effects Illustrator andor FigmaFamiliar with graphic designproduct design principlesApplicants must be legally authorized to work in the US\nBenefits of working for us\nFlexible schedule  work around your life and needs we dont count your hoursUnlimited Paid Time Off  yes reallyFully remote Comprehensive health insuranceVision and dental insuranceGroup life InsuranceQuarterly employee bonuses401K retirement planYearly company retreatPotential for customer event accessCompany provided laptop and general office supplies\nBenefits available for fulltime employees only\nCompensation\nThis is a parttime fully remote position The wage for this position is 20hour with a maximum of 20 hours per week\nAbout the team\nEventeny was founded on the belief that managing largescale events with hundreds of exhibitors vendors sponsors and volunteers should not be stressful and burdensome Our mission is to remove event organizers from being the 5th most stressful job in the world Thats why we built Eventeny and continue to work every day on the biggest problems in the event industry We dont just dream it we build it Today Eventeny serves more than 7500 large festivals and conventions worldwide\nOur customers come from all walks of life and so do we We hire great people from a wide variety of backgrounds not just because its the right thing to do but because it makes our company stronger We dont think we should have to advertise that were LGBTQIA neurodivergent and disability friendly or that we put our employees mental and physical health before everything else but we do because its not the norm for most companies yet\nWere a diverse inclusive and welcoming team of individuals who thrive in a fastpaced and everchanging environment Our team works closely together to brainstorm and improve our processes and the customer experience every single day We prioritize our work based whats best for our customers not  ...
# ('fulwell 73 productions', 2, 'We are seeking smart motivated interns for the Fall 2023 period looking for exposure to unscripted television development and production This will be an in person internship and a great opportunity for those who are interested in pursuing a career within development production creative affairs or other related fields Interns will gain insight and knowledge of the industry by way of practical work experience such as script coverage research creating and maintaining lists of available actors writers and directors and other various projects to gain exposure to all facets of the business\nDuties will includeLogging and updating company databases and development gridsCreating talent listsResearching upandcoming talent IP and formatsWriting and designing onesheets treatments and pitch decksPitching projects to the team\nWhat were looking for in candidatesExceptional organizational and administrative skillsGreat interpersonal skillsInterested in gaining experience in both scripted and unscripted entertainmentAble to multitask in a fastpaced environmentHave a passion for television film and digital contentFinger on the pulse of entertainment and pop cultureCando notasktoosmall attitude', 1)
# ('hcvt', 4, 'Focus Clarity Commitment\nHCVT is a highly specialized professional services firm providing tax audit business management mergers and acquisitions and valuation services to private and public companies business owners high net worth individuals and family offices across select industry niches\nAt HCVT we are different We are a team driven by our valuesIntegrity at our Core Building Success Together and a Passion for Excellence Our focus and commitment are on the needs of our clients and our team Clarifying and resolving complex issues is what we do How we do it is what sets us apart from other CPA firms\nAs part of the HCVT team you will work in a fastpaced environment Our culture is all about collaboration teamwork giving back to our communities and partner access and accountability We also believe that there is no one way to progress in your career We are flexible and embrace diversity We provide our team members the right tools to be successful with a continual focus on technical training as well as other skills necessary to thrive in the world of public accounting Join HCVT and Move Forward  Your Way\nAs an Intern in our Tax service line you will be responsible for the following\nPrepare federal and multistate income tax returns for individuals partnerships corporations and trusts and its related income tax work papersComplete a variety of projects within engagement timeline and budget guidelinesLearn and effectively utilize firm tax preparation software to continually learn share knowledge with team members and enhance the quality of service to clientsPerform selfreview of workPerform tax technical research assigned by supervisors Develop strong relationships with firm professionals Participate in firm training and activitiesWork with your buddy and performance manager on professional development of both technical and soft skills\nTo be successful these are the skills qualities and experience you will need\nOn track to completing a bachelors degree in accounting or a masters degree in accounting or taxation between December 2025  July 2026Available to work 40 hours a week from MidJune through MidAugustMinimum overall and accounting GPAs of 30Active membership in Beta Alpha Psi or another campus accounting organization Strong technical aptitude and demonstrate effective verbal and written communication skillsExhibit leadership skills that demonstrate strong judgement problemsolving and decisionmaking abilities Able to learn in a fast paced environment and receptive to feedback and coachingAbility to multitask prioritize responsibilities and take initiative on projectsHigh attention to detail A positive attitude and is a team player mentality with a cando spirit\nHow To Apply\nSelect the office youre most interested in and submit an application  httpsjobslevercohcvtRequired documents  Resume Unofficial TranscriptsNote  HCVT is unable to sponsor the work authorization of candidates\nConnect With Us\nLinkedIn Instagram Facebook HCVT Website\nThe ordinance requires employers to state in all job solicitations postings and advertisements that the employer will consider applicants in a manner consistent with the requirements of the Fair Chance Initiative', 1)
# ('openpark', 1, 'OpenParkus a pet wellness and technology startup is seeking talented and enthusiastic interns to join our team and contribute to our mission of making the world a more petfriendly place This is a unique chance to gain valuable handson experience and make a meaningful impact in the petcare industry\nAboutAt OpenParkus we are passionate about the wellbeing of people  pets Our vision is to create innovative solutions that enhance the lives of savvy pet parents and their furry families We combine cuttingedge technology with a deep understanding of pet wellness to deliver outstanding products and services\nOverviewAs an intern at OpenParkus you will be an integral part of our dynamic and collaborative team You will work closely with industry experts gain practical skills and contribute to realworld projects We value creativity innovation and a commitment to excellence This is a fantastic opportunity to learn grow and shape the future of the pet industry\nQualificationsCurrently pursuing a Bachelors or Masters degree in a relevant field Marketing Engineering Computer Science Information Security Business Administration Finance or related disciplinesStrong passion for pets and an interest in the pet industryExcellent communication and interpersonal skillsProactive selfmotivated and able to work both independently and collaborativelyStrong analytical and problemsolving abilitiesProficient in relevant software tools and technologies specific requirements vary by role\nOpenParkus is an equal opportunity employer We value diversity and welcome applications from individuals of all backgrounds Join OpenParkus today and be a part of a community dedicated to making the world more pet friendly', 1)
# ('power digital marketing', 4, 'About the CompanyPower Digital is a leading datadriven marketing company that is nationally recognized for its ability to combine the best of art and science As a peoplefirst agency we value diversity in backgrounds and experiences We strongly believe our people and culture are key to our success With a 91 employee retention rate Power Digital has continued to build and foster an incredible team of 600 talented driven and growthminded marketers who drive business results for our client partners and have fun while doing so We are on a mission to be the most wellrespected marketing services company in the world\nAs a fullservice firm the company offers bestinclass services including SEO Content Marketing Paid Media Social Media Marketing Programmatic  CTV Public Relations Influencer Marketing Email  SMS Conversion Rate Optimization Amazon Marketing Creative and Web Development Power Digital is hyperfocused on helping brands scale revenue and increase profits by using data and analytics to guide strategy ultimately driving irrefutable value for clients\nUnique to Power Digital is their proprietary marketing platform SPRnovaTM that can analyze any businesss growth opportunities with a corresponding roadmap of how to execute and track progress across every marketing channel Leveraging their team of the nations leading consumer strategists creatives and data analysts Power Digital provides scalable and tangible marketing solutions for each stage of the funnel and for every milestone of the consumer journey\n\nInternship Position DetailsPosition Title SEO InternInternship Term Fall 2023Compensation College credit MUST be enrolled in college courseDesired Fields of Study Business Advertising MarketingHours Desired 1520 hours per weekThis is a remote opportunity open to anyone legally eligible to work in the US\nAbout the RoleThe goal of this internship is to learn search engine optimization best practices and implement those learnings through handson client projects Build a wellrounded digital marketing skillset and get experience working at a fullservice marketing agency\nResponsibilitiesBe prepared to learn and understand search engine optimization techniques strategies and processesOptimize and edit website copyComplete keyword researchWrite title tags and meta descriptionsIdentify internal linking opportunitiesImplement optimizations to client websites no coding experience requiredAssist the SEO team with ad hoc projectsLearn to perform competitive analysisLearn and use Google Analytics Google Webmaster Tools and other industry leading SEO tools\nSkillsExperience RequiredStrong interest in a career that blends analytics looking at data and performance trends and creativity helping write web copy and meta data especially within the fields of search marketing advertising and marketing as a wholeExcellent oral and written communication skillsComputer skills thorough understanding of MS Office Excel PowerPoint Google DriveTime management skills ability to prioritize tasks for efficient executionStrong work ethic must be selfmotivated and able to take initiativeBasic understanding of HTML is a plus but not requiredAbility to function in a team environment\nPower Digitals people and culture are at the core of our success which is why diversity in our teams backgrounds and experiences are paramount We are an Equal Opportunity Employer and our employees are people with different strengths experiences and backgrounds who strive to make an impact inside and outside of the workplace Diversity not only includes race and gender identity but also age disability status veteran status sexual orientation religion and many other parts of ones identity All of our employees points of view are key to our success and inclusion is everyones responsibility\nPlease be aware of fictitious job openings consulting engagements solicitations or employment offers from suspicious sources These engagements may be an attempt to obta ...
# ('student world impact film festival (swiff)', 4, 'Location Remote\nDuration 5 months October 10 2023  March 11 2024\nAbout the Student World Impact Film FestivalThe Student World Impact Film Festival SWIFF is the largest student film festival in the world with over 15000 submissions from 120 countries yearly The festival aims to showcase impactful films that address important social and environmental issues and inspire positive change The festival provides a platform for emerging filmmakers to showcase their work and for audiences to engage with the issues that matter most to them\nJob Responsibilities\nIndependently review and evaluate films based on preestablished criteriaCommit 10 hours per week to the internship flexibly distributed during the week based on each interns scheduleApply analysis skills to assess each film in conveying its message and impact\nQualifications\nMay be enrolled in universitycollege or high school or have graduated from schoolStrong interest in film and social impactExcellent attention to detail and ability to work independently\nBenefits\nJoin the multicultural team of the fastestgrowing global student film festival globallyGain valuable experience in film festival management and jury processesNetwork with professionals and emerging filmmakers from around the worldDevelop skills in film evaluation and analysisReceive a certificate of completion at the end of the internship\nThis is an unpaid internship but it offers an excellent opportunity for individuals who are passionate about film to gain valuable experience and be part of a global team of filmmakers\n', 1)
# Database connection closed.
